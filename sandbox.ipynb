# %%
import numpy as np
import scipy.stats

total = [6.835363851604415, 6.211394877879391, 6.020415481916819, 5.939784981834157, 5.394749270201458, 5.941306292827881, 5.590183153602758, 5.440703016367507, 5.826137465730321, 6.032863365921191, 6.534721438201223 ]
A = [12.682631327397548, 13.364320215062111, 10.149387088920648, 13.012112824769439, 11.269189479256305, 12.11398420926589, 11.10734615157152, 10.686731217447493, 12.237628095801117, 11.296962117579604, 11.993919790426597]
B = [7.735645169293131, 6.467561959709445, 7.666814640867002,5.678695254295477,  5.03330890680217, 5.455320555950695, 5.227389756189651, 5.5958229492964175, 5.631314702040868, 6.1197060085359665, 7.145379977228034]
C = [1.0528333005445394, 0.9967880081449829, 1.2463033355421076, 1.7293401478563772, 1.6275752021633425, 1.9207894076838177, 0.8026853721684262, 1.2035437413764918, 0.8711014081100709, 1.2107239609763665, 1.3690810639005642 ]
D = [6.157662067038393, 5.797538856979525, 5.4158999167208375, 5.358940695053552, 5.206309952033977, 5.622545355877581, 5.682877142955064, 5.1163545118070095, 5.7590062404662365, 6.200899928279491, 6.709234834900193]
E = [5.605205842161294, 4.491197623831657, 4.355547467488558, 4.642301833994944, 4.293220604922171, 5.068795547151232, 4.8305231979309085, 4.4180543556476595, 4.594512227647253, 4.8059471556766145, 4.700532817776987]

print(np.mean(np.array(total)))
# Out:
# 5.978874836007919

# %%
def mean_confidence_interval(data, confidence=0.95):
    a = 1.0 * np.array(data)
    n = len(a)
    m, se = np.mean(a), scipy.stats.sem(a)
    h = se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)
    return m, m-h, m+h

print(mean_confidence_interval(total))
print(mean_confidence_interval(A))
print(mean_confidence_interval(B))
print(mean_confidence_interval(C))
print(mean_confidence_interval(D))
print(mean_confidence_interval(E))
# Out:
# (5.978874836007919, 5.685314553105762, 6.272435118910076)
# (11.810382956136207, 11.138562280478475, 12.48220363179394)
# (6.159723625473532, 5.512357348161116, 6.807089902785949)
# (1.2755240862242805, 1.0352020334608092, 1.5158461389877518)
# (5.72975177291926, 5.409680886028729, 6.0498226598097915)
# (4.709621697657207, 4.457866533881656, 4.961376861432758)
